# %%
# DATA CLEANING AND VISUALIZATION
# IMPORTING THE LIBRARIES
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer

pd.set_option("display.max_colwidth", 400)

# %%
# IMPORTING DATA
train_data=pd.read_csv("./Data/TrainingData.csv")
test_data=pd.read_csv("./Data/SubtaskA_Trial_Test_Labeled.csv")
valid_data=pd.read_csv("./Data/SubtaskA_EvaluationData_labeled.csv")

# %%
# PEAKING INTO DATA AND ITS FEATURES
print(train_data.shape)
train_data.head()
# Out:
# (8500, 3)
#       id  \
# 0  663_3
# 1  663_4
# 2  664_1
# 3  664_2
# 4  664_3
#
#                                                                                                                                                                                                                                                                                      sentence  \
# 0                "Please enable removing language code from the Dev Center "language history" For example if you ever selected "ru" and "ru-ru" laguages and you published this xap to the Store then it causes Tile localization to show the en-us(default) tile localization which is bad."
# 1  "Note: in your .csproj file, there is a SupportedCultures entry like this: <SupportedCultures>de-DE;ru;ru-RU </SupportedCultures> When I removed the "ru" language code and published my new xap version, the old xap version still remains in the Store with "Replaced and unpublished"."
# 2                                                                                                                                                                                "Wich means the new version not fully replaced the old version and this causes me very serious problems: 1."
# 3                                                                                                                                                                                                                        "Some of my users will still receive the old xap version of my app."
# 4                                                                                                                                                                                                                    "The store randomly gives the old xap or the new xap version of my app."
#
#    label
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
print(test_data.shape)
test_data.head()
# Out:
# (592, 3)
#        id  \
# 0  1310_1
# 1  1312_1
# 2  1313_1
# 3  1313_2
# 4  1313_3
#
#                                                                                                                                                                                                                                                               sentence  \
# 0                                                                                                                                     I'm not asking Microsoft to Gives permission like Android so any app can take my data, but don't keep it restricted like iPhone.
# 1                                                                                                                                                                                                                                somewhere between Android and iPhone.
# 2                                                                                                                                                                                          And in the Windows Store you can flag the App [Requires Trust] for example.
# 3  Many thanks Sameh Hi, As we know, there is a lot of limitations is WP8 OS due the high security in the OS itself which is very good, but some time we need to allow some apps to do extra works, apps which we trust i.e: hotmail app, facebook app, skype app ....
# 4                                                                                                                                   The idea is that we can develop a regular app and we request our permissions in the manifest, OR the app can ASK FOR TRUST_�_ more
#
#    label
# 0      1
# 1      0
# 2      0
# 3      0
# 4      1

# %%
print(valid_data.shape)
valid_data.head()
# Out:
# (833, 3)
#      id  \
# 0  9566
# 1  9569
# 2  9576
# 3  9577
# 4  9579
#
#                                                                                                                                                                                          sentence  \
# 0                                                                                                                                                      This would enable live traffic aware apps.
# 1                                                                                              Please try other formatting like bold italics shadow to distinguish titles/subtitles from content.
# 2  Since computers were invented to save time I suggest we be allowed to upload them all in one zip file - using numbering for the file names and the portal could place them in the right order.
# 3                                                                                                                                             Allow rearranging if the user wants to change them!
# 4                                                                                                               Add SIMD instructions for better use of ARM NEON instructions for math and games.
#
#    label
# 0      0
# 1      1
# 2      1
# 3      1
# 4      1

# %%
# GETTING THE MAXIMUM LENGTH OF THE STRING
len_train= train_data['sentence'].str.len()
print(len_train)
# Out:
# 0       268
# 1       282
# 2       108
# 3        68
# 4        72
#        ...
# 8495     67
# 8496    111
# 8497    110
# 8498    179
# 8499    186
# Name: sentence, Length: 8500, dtype: int64

# %%
# APPENDING ALL THE DATA INTO ONE TO EASE THE CLEANING PROCESS
combined= train_data.append(test_data,ignore_index=True)
combined= combined.append(valid_data,ignore_index=True)
print(combined.shape)
combined.head()
# Out:
# (9925, 3)
#       id  \
# 0  663_3
# 1  663_4
# 2  664_1
# 3  664_2
# 4  664_3
#
#                                                                                                                                                                                                                                                                                      sentence  \
# 0                "Please enable removing language code from the Dev Center "language history" For example if you ever selected "ru" and "ru-ru" laguages and you published this xap to the Store then it causes Tile localization to show the en-us(default) tile localization which is bad."
# 1  "Note: in your .csproj file, there is a SupportedCultures entry like this: <SupportedCultures>de-DE;ru;ru-RU </SupportedCultures> When I removed the "ru" language code and published my new xap version, the old xap version still remains in the Store with "Replaced and unpublished"."
# 2                                                                                                                                                                                "Wich means the new version not fully replaced the old version and this causes me very serious problems: 1."
# 3                                                                                                                                                                                                                        "Some of my users will still receive the old xap version of my app."
# 4                                                                                                                                                                                                                    "The store randomly gives the old xap or the new xap version of my app."
#
#    label
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0

# %%
# PART 1: REMOVING THE DIGITS PUNCHTUATION AND SPECIAL CHARACTERS 
combined['clean']=combined['sentence'].str.replace("[^a-zA-Z#]"," ")
combined.head()
# Out:
#       id  \
# 0  663_3
# 1  663_4
# 2  664_1
# 3  664_2
# 4  664_3
#
#                                                                                                                                                                                                                                                                                      sentence  \
# 0                "Please enable removing language code from the Dev Center "language history" For example if you ever selected "ru" and "ru-ru" laguages and you published this xap to the Store then it causes Tile localization to show the en-us(default) tile localization which is bad."
# 1  "Note: in your .csproj file, there is a SupportedCultures entry like this: <SupportedCultures>de-DE;ru;ru-RU </SupportedCultures> When I removed the "ru" language code and published my new xap version, the old xap version still remains in the Store with "Replaced and unpublished"."
# 2                                                                                                                                                                                "Wich means the new version not fully replaced the old version and this causes me very serious problems: 1."
# 3                                                                                                                                                                                                                        "Some of my users will still receive the old xap version of my app."
# 4                                                                                                                                                                                                                    "The store randomly gives the old xap or the new xap version of my app."
#
#    label  \
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#
#                                                                                                                                                                                                                                                                                         clean
# 0                 Please enable removing language code from the Dev Center  language history  For example if you ever selected  ru  and  ru ru  laguages and you published this xap to the Store then it causes Tile localization to show the en us default  tile localization which is bad
# 1   Note  in your  csproj file  there is a SupportedCultures entry like this   SupportedCultures de DE ru ru RU   SupportedCultures  When I removed the  ru  language code and published my new xap version  the old xap version still remains in the Store with  Replaced and unpublished
# 2                                                                                                                                                                                 Wich means the new version not fully replaced the old version and this causes me very serious problems
# 3                                                                                                                                                                                                                         Some of my users will still receive the old xap version of my app
# 4                                                                                                                                                                                                                     The store randomly gives the old xap or the new xap version of my app

# %%
# PART 2: TOKENIZING THE SENTENCES TO REMOVE STOP WORDS AND STEMMING PROCESS
tokenized_sentence= combined['clean'].apply(lambda x: x.split())
tokenized_sentence.head()
# Out:
# 0           [Please, enable, removing, language, code, from, the, Dev, Center, language, history, For, example, if, you, ever, selected, ru, and, ru, ru, laguages, and, you, published, this, xap, to, the, Store, then, it, causes, Tile, localization, to, show, the, en, us, default, tile, localization, which, is, bad]
# 1    [Note, in, your, csproj, file, there, is, a, SupportedCultures, entry, like, this, SupportedCultures, de, DE, ru, ru, RU, SupportedCultures, When, I, removed, the, ru, language, code, and, published, my, new, xap, version, the, old, xap, version, still, remains, in, the, Store, with, Replaced, and, unpublished]
# 2                                                                                                                                                                                                   [Wich, means, the, new, version, not, fully, replaced, the, old, version, and, this, causes, me, very, serious, problems]
# 3                                                                                                                                                                                                                                            [Some, of, my, users, will, still, receive, the, old, xap, version, of, my, app]
# 4                                                                                                                                                                                                                                       [The, store, randomly, gives, the, old, xap, or, the, new, xap, version, of, my, app]
# Name: clean, dtype: object

# %%
# REMOVING THE STOP WORDS LIKE A, AN, AT, BY ETC
# nltk.download('stopwords')
# This caching makes the processing of thousands of strings very fast!
cachedStopWords = stopwords.words("english")
tokenized_sentence = tokenized_sentence.apply(
    lambda sentence: [word for word in sentence if word not in cachedStopWords]
)
tokenized_sentence.head()
# Out:
# 0                                     [plea, enabl, remov, languag, code, dev, center, languag, histori, exampl, ever, select, ru, ru, ru, laguag, publish, xap, store, cau, tile, local, show, en, us, default, tile, local, bad]
# 1    [note, csproj, file, supportedcultur, entri, like, supportedcultur, de, DE, ru, ru, RU, supportedcultur, I, remov, ru, languag, code, publish, new, xap, version, old, xap, version, still, remain, store, replac, unpublish]
# 2                                                                                                                                                    [wich, mean, new, version, fulli, replac, old, version, cau, seriou, problem]
# 3                                                                                                                                                                                    [user, still, receiv, old, xap, version, app]
# 4                                                                                                                                                                        [store, randomli, give, old, xap, new, xap, version, app]
# Name: clean, dtype: object

# %%
# PART 3: CONVERTING WORDS TO THE LOWER CASES
tokenized_sentence = tokenized_sentence.apply(
    lambda sentence: [word.lower() for word in sentence]
)
tokenized_sentence.head()
# Out:
# 0                                     [plea, enabl, remov, languag, code, dev, center, languag, histori, exampl, ever, select, ru, ru, ru, laguag, publish, xap, store, cau, tile, local, show, en, us, default, tile, local, bad]
# 1    [note, csproj, file, supportedcultur, entri, like, supportedcultur, de, de, ru, ru, ru, supportedcultur, i, remov, ru, languag, code, publish, new, xap, version, old, xap, version, still, remain, store, replac, unpublish]
# 2                                                                                                                                                    [wich, mean, new, version, fulli, replac, old, version, cau, seriou, problem]
# 3                                                                                                                                                                                    [user, still, receiv, old, xap, version, app]
# 4                                                                                                                                                                        [store, randomli, give, old, xap, new, xap, version, app]
# Name: clean, dtype: object

# %%
# PART 4: USING NLTK PORTER STEMMER FOR STEMMING(CHANGINH WORDS OF DIFFERENT FROMS INTO ONE FORM)
stemmer =  PorterStemmer()
tokenized_sentence = tokenized_sentence.apply(lambda x: [stemmer.stem(i) for i in x] )
tokenized_sentence.head()
# Out:
# 0                                     [plea, enabl, remov, languag, code, dev, center, languag, histori, exampl, ever, select, ru, ru, ru, laguag, publish, xap, store, cau, tile, local, show, en, us, default, tile, local, bad]
# 1    [note, csproj, file, supportedcultur, entri, like, supportedcultur, de, de, ru, ru, ru, supportedcultur, i, remov, ru, languag, code, publish, new, xap, version, old, xap, version, still, remain, store, replac, unpublish]
# 2                                                                                                                                                    [wich, mean, new, version, fulli, replac, old, version, cau, seriou, problem]
# 3                                                                                                                                                                                    [user, still, receiv, old, xap, version, app]
# 4                                                                                                                                                                        [store, randomli, give, old, xap, new, xap, version, app]
# Name: clean, dtype: object

# %%
# DETOKNEIZING THE WORDS TO FORM SENTENCES AGAIN
detokenized_sentence= tokenized_sentence.apply(lambda x: ' '.join(x))
detokenized_sentence.head()
# Out:
# 0                                    plea enabl remov languag code dev center languag histori exampl ever select ru ru ru laguag publish xap store cau tile local show en us default tile local bad
# 1    note csproj file supportedcultur entri like supportedcultur de de ru ru ru supportedcultur i remov ru languag code publish new xap version old xap version still remain store replac unpublish
# 2                                                                                                                                 wich mean new version fulli replac old version cau seriou problem
# 3                                                                                                                                                             user still receiv old xap version app
# 4                                                                                                                                                   store randomli give old xap new xap version app
# Name: clean, dtype: object

# %%
# THE BELOW DATA SHOWS THE REDUCTION IN THE CHARACTERS AFTER THE CLEANING PROCESS
combined['clean']=detokenized_sentence
combined.head()
# Out:
#       id  \
# 0  663_3
# 1  663_4
# 2  664_1
# 3  664_2
# 4  664_3
#
#                                                                                                                                                                                                                                                                                      sentence  \
# 0                "Please enable removing language code from the Dev Center "language history" For example if you ever selected "ru" and "ru-ru" laguages and you published this xap to the Store then it causes Tile localization to show the en-us(default) tile localization which is bad."
# 1  "Note: in your .csproj file, there is a SupportedCultures entry like this: <SupportedCultures>de-DE;ru;ru-RU </SupportedCultures> When I removed the "ru" language code and published my new xap version, the old xap version still remains in the Store with "Replaced and unpublished"."
# 2                                                                                                                                                                                "Wich means the new version not fully replaced the old version and this causes me very serious problems: 1."
# 3                                                                                                                                                                                                                        "Some of my users will still receive the old xap version of my app."
# 4                                                                                                                                                                                                                    "The store randomly gives the old xap or the new xap version of my app."
#
#    label  \
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#
#                                                                                                                                                                                             clean
# 0                                  plea enabl remov languag code dev center languag histori exampl ever select ru ru ru laguag publish xap store cau tile local show en us default tile local bad
# 1  note csproj file supportedcultur entri like supportedcultur de de ru ru ru supportedcultur i remov ru languag code publish new xap version old xap version still remain store replac unpublish
# 2                                                                                                                               wich mean new version fulli replac old version cau seriou problem
# 3                                                                                                                                                           user still receiv old xap version app
# 4                                                                                                                                                 store randomli give old xap new xap version app

# %%
# SAVING THE CLEANED DATA TO DISK
combined.to_csv('CleanData.csv', encoding='utf-8', index=False)

# %%
# VISUALIZING THE COMMON WORDS IN SUGGESTIONS AND NORMAL WORDS
from wordcloud import WordCloud
def generateImage(words):
    wordcloud = WordCloud(width=1200,height=500,random_state=21,max_font_size=110).generate(words)
    plt.figure(figsize=(15,10))
    plt.imshow(wordcloud,interpolation='bilinear')
    plt.axis('off')
    plt.show()

# %%
# COMMON WORDS IN NORMAL SENTENCES
normal_words=' '.join([text for text in combined['clean'][combined['label']==0]])
generateImage(normal_words)

# %%
# COMMON WORDS IN SUGGESTIVE SENTENCES
suggestion_words=' '.join([text for text in combined['clean'][combined['label']==1]])
generateImage(suggestion_words)

# %%
# NO ACCURATE CONCLUSION CAN BE OBTAINED BY LOOKING AT THE FREQUNET WORDS IN THE CLASSES! NEED TO HAVE A MODEL FOR 
# ACCURATELY CLASSIFYING THE SENTENCES
